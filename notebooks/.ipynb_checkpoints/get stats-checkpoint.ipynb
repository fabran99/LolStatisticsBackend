# %%
from api.riot_api_routes import *
from api.variables import SERVER_ROUTES, SERVER_REAL_NAME_TO_ROUTE, DIVISIONS, TIERS, GAME_TYPE,MAIN_GAMEMODE,RANKED_QUEUES, MATCHES_STATS_KEYS

import json
from django.conf import settings
from os import path
import os
import random

import pandas as pd
from time import sleep

league_data_route=path.join(settings.PREPROCESS_PATH, "league_data.json")
player_sample_route=path.join(settings.PREPROCESS_PATH, "player_sample.json")
matches_sample_route=path.join(settings.PREPROCESS_PATH, "matches_sample.csv")
champ_ban_file=path.join(settings.PREPROCESS_PATH, "champ_ban.csv")
champ_data_file=path.join(settings.PREPROCESS_PATH, "champ_data.csv")
playstyle_data_file=path.join(settings.PREPROCESS_PATH, "playstyle_data.csv")

# %%
champ_data = pd.read_csv(champ_data_file)
len(champ_data)
# Out:
# 146550

# %%
high_elo_divisions = ["PLATINUM","DIAMOND",'grandmasters', 'challengers', 'masters']
high_elo_data = champ_data.loc[champ_data['division'].isin(high_elo_divisions)]
high_elo_data
# Out:
#         championId  teamId         role    lane  spell1Id  spell2Id  \
# 20             235     100  DUO_SUPPORT  BOTTOM         4         7
# 21             555     100    DUO_CARRY  BOTTOM        14         4
# 22               7     100         SOLO  MIDDLE         4        14
# 23              86     100         SOLO     TOP         4        14
# 24             120     100         NONE  JUNGLE        11         6
# ...            ...     ...          ...     ...       ...       ...
# 146515          61     200         SOLO  MIDDLE        12         4
# 146516          12     200  DUO_SUPPORT  BOTTOM         4        14
# 146517          39     200         SOLO     TOP         4        12
# 146518         523     200    DUO_CARRY  BOTTOM         4         7
# 146519          60     200         NONE  JUNGLE         4        11
#
#         gameDuration tier  division    win  ...  perk1  perk2  perk3  perk4  \
# 20              1740   II  PLATINUM  False  ...   8304   8345   8410   8009
# 21              1740   II  PLATINUM  False  ...   8463   8473   8242   8136
# 22              1740   II  PLATINUM  False  ...   8143   8138   8135   8345
# 23              1740   II  PLATINUM  False  ...   9111   9105   8014   8473
# 24              1740   II  PLATINUM  False  ...   9111   9104   8014   8234
# ...              ...  ...       ...    ...  ...    ...    ...    ...    ...
# 146515          1342  III  PLATINUM  False  ...   8226   8210   8237   8304
# 146516          1342  III  PLATINUM  False  ...   8446   8429   8451   8345
# 146517          1342  III  PLATINUM  False  ...   9111   9104   8299   8345
# 146518          1342  III  PLATINUM  False  ...   9111   9103   8014   8275
# 146519          1342  III  PLATINUM  False  ...   9111   9104   8014   8275
#
#         perk5  perkPrimaryStyle  perkSubStyle  statPerk0  statPerk1  statPerk2
# 20       8014              8300        8000.0       5008       5008       5002
# 21       8106              8400        8100.0       5008       5008       5002
# 22       8352              8100        8300.0       5008       5008       5003
# 23       8446              8000        8400.0       5005       5008       5002
# 24       8232              8000        8200.0       5005       5008       5002
# ...       ...               ...           ...        ...        ...        ...
# 146515   8345              8200        8300.0       5008       5008       5003
# 146516   8347              8400        8300.0       5007       5002       5001
# 146517   8352              8000        8300.0       5005       5008       5002
# 146518   8236              8000        8200.0       5005       5008       5002
# 146519   8232              8000        8200.0       5005       5008       5002
#
# [58870 rows x 38 columns]

# %%
total_matches = len(high_elo_data)/10
total_matches
# Out:
# 5887.0

# %%
champs = high_elo_data['championId'].unique()
pickrate=[]
for ch in champs:
    total_with_champ = high_elo_data.loc[(high_elo_data['championId'] == ch)]
    pickrate.append({
        "championId":ch,
        "pickrate":len(total_with_champ) * 100 / total_matches,
        "winrate":len(total_with_champ.loc[total_with_champ['win']==True] ) * 100 / len(total_with_champ),
        "total_picked":len(total_with_champ)
    })

# %%
data_per_champ = pd.DataFrame(pickrate)
data_per_champ
# Out:
#      championId   pickrate    winrate  total_picked
# 0           235  15.355869  51.880531           904
# 1           555  10.395787  50.000000           612
# 2             7   6.607780  48.329049           389
# 3            86   8.663156  46.078431           510
# 4           120   4.195685  51.417004           247
# ..          ...        ...        ...           ...
# 143         136   1.257007  58.108108            74
# 144          31   3.227450  51.578947           190
# 145          77   1.053168  56.451613            62
# 146          90   3.295397  47.938144           194
# 147         102   3.635128  50.000000           214
#
# [148 rows x 4 columns]

# %%
data_per_champ.sort_values("pickrate", ascending=False).tail(10)
# Out:
#      championId  pickrate    winrate  total_picked
# 15           74  1.936470  53.508772           114
# 76           83  1.885510  53.153153           111
# 121          42  1.834551  53.703704           108
# 137           1  1.579752  50.537634            93
# 141         427  1.562765  55.434783            92
# 114          96  1.426873  53.571429            84
# 117         133  1.324953  61.538462            78
# 143         136  1.257007  58.108108            74
# 145          77  1.053168  56.451613            62
# 13           72  0.951249  51.785714            56

# %%
champ_ban = pd.read_csv(champ_ban_file)
champ_ban.head()
# Out:
#    championId  pickTurn division tier   win
# 0          53         1     IRON  III  True
# 1         875         2     IRON  III  True
# 2         555         3     IRON  III  True
# 3          55         4     IRON  III  True
# 4         516         5     IRON  III  True

# %%
champ_ban = champ_ban.loc[champ_data['division'].isin(high_elo_divisions)]
champ_ban['championId'].value_counts()
# Out:
# 38     2617
# 122    2425
# 62     2383
# 157    2125
# 25     2037
#        ...
# 42        9
# 14        8
# 72        8
# 115       8
# 15        4
# Name: championId, Length: 149, dtype: int64

# %%
winrate_on_ban=[]

for champ in champ_ban['championId'].unique():
    total = len(champ_ban.loc[(champ_ban['championId'] == champ)])
    win = len(champ_ban.loc[(champ_ban['championId'] == champ) & (champ_ban['win']==True)])
    winrate = win * 100 / total
    winrate_on_ban.append({
        "championId":champ,
        "winrate":winrate,
        "total":total
    })
pd.DataFrame(winrate_on_ban).sort_values("total", ascending=False).head(10)
# Out:
#     championId    winrate  total
# 3           38  49.828047   2617
# 0          122  48.247423   2425
# 6           62  50.062946   2383
# 12         157  50.400000   2125
# 4           25  49.631811   2037
# 9          875  50.049554   2018
# 11         350  51.509872   1722
# 2          111  51.679434   1697
# 13         235  50.297265   1682
# 28         523  48.300537   1677

# %%
# Out:
# 1

# %%
winrate_on_ban['winrate']= * 100 / len(winrate_on_ban[])

# %%
len(winrate_on_ban['championId'])
# Out:
# 50

# %%
psd = pd.read_csv(playstyle_data_file)
psd
# Out:
#     championId  teamId         role    lane  gameDuration tier division  \
# 0          201     100  DUO_SUPPORT  BOTTOM          1258   IV   SILVER
# 1          161     100         SOLO  MIDDLE          1258   IV   SILVER
# 2           22     100    DUO_CARRY  BOTTOM          1258   IV   SILVER
# 3           83     100         SOLO     TOP          1258   IV   SILVER
# 4           72     100         NONE  JUNGLE          1258   IV   SILVER
# 5           39     200         SOLO  MIDDLE          1258   IV   SILVER
# 6          114     200         SOLO     TOP          1258   IV   SILVER
# 7          121     200         NONE  JUNGLE          1258   IV   SILVER
# 8          412     200  DUO_SUPPORT  BOTTOM          1258   IV   SILVER
# 9           21     200    DUO_CARRY  BOTTOM          1258   IV   SILVER
# 10          82     100         SOLO     TOP          1471    I     IRON
# 11         111     100  DUO_SUPPORT  BOTTOM          1471    I     IRON
# 12          11     100         NONE  JUNGLE          1471    I     IRON
# 13           3     100         SOLO  MIDDLE          1471    I     IRON
# 14         202     100    DUO_CARRY  BOTTOM          1471    I     IRON
# 15          18     200    DUO_CARRY  BOTTOM          1471    I     IRON
# 16         120     200         NONE  JUNGLE          1471    I     IRON
# 17          83     200         SOLO     TOP          1471    I     IRON
# 18         161     200         SOLO  MIDDLE          1471    I     IRON
# 19         117     200  DUO_SUPPORT  BOTTOM          1471    I     IRON
# 20          25     100         SOLO  MIDDLE          1563  III   BRONZE
# 21         117     100  DUO_SUPPORT  BOTTOM          1563  III   BRONZE
# 22          24     100         SOLO     TOP          1563  III   BRONZE
# 23          59     100         NONE  JUNGLE          1563  III   BRONZE
# 24          51     100    DUO_CARRY  BOTTOM          1563  III   BRONZE
# 25          56     200         SOLO  MIDDLE          1563  III   BRONZE
# 26          54     200  DUO_SUPPORT  BOTTOM          1563  III   BRONZE
# 27          33     200         NONE  JUNGLE          1563  III   BRONZE
# 28          21     200    DUO_CARRY  BOTTOM          1563  III   BRONZE
# 29         104     200         SOLO     TOP          1563  III   BRONZE
# 30          11     100         NONE  JUNGLE          1869   II   BRONZE
# 31          75     100         SOLO     TOP          1869   II   BRONZE
# 32         222     100    DUO_CARRY  BOTTOM          1869   II   BRONZE
# 33         111     100  DUO_SUPPORT  BOTTOM          1869   II   BRONZE
# 34         103     100         SOLO  MIDDLE          1869   II   BRONZE
# 35          36     200         NONE  JUNGLE          1869   II   BRONZE
# 36          58     200         SOLO     TOP          1869   II   BRONZE
# 37          99     200         SOLO  MIDDLE          1869   II   BRONZE
# 38         157     200    DUO_CARRY  BOTTOM          1869   II   BRONZE
# 39         117     200  DUO_SUPPORT  BOTTOM          1869   II   BRONZE
# 40          41     100         SOLO     TOP          1821   II   SILVER
# 41          21     100    DUO_CARRY  BOTTOM          1821   II   SILVER
# 42         235     100  DUO_SUPPORT  BOTTOM          1821   II   SILVER
# 43          72     100         NONE  JUNGLE          1821   II   SILVER
# 44          61     100         SOLO  MIDDLE          1821   II   SILVER
# 45          24     200         NONE  JUNGLE          1821   II   SILVER
# 46          25     200  DUO_SUPPORT  BOTTOM          1821   II   SILVER
# 47         105     200         SOLO  MIDDLE          1821   II   SILVER
# 48          55     200         SOLO     TOP          1821   II   SILVER
# 49          51     200    DUO_CARRY  BOTTOM          1821   II   SILVER
#
#       win  kills  assists  ...  totalDamageDealtToChampions  \
# 0    True      2       20  ...                         6712
# 1    True      6       12  ...                        23061
# 2    True     12       13  ...                        14988
# 3    True      3        5  ...                         9436
# 4    True     10        3  ...                         6839
# 5   False      3        2  ...                         8423
# 6   False      3        2  ...                        10014
# 7   False      2        1  ...                         3502
# 8   False      3        4  ...                         6205
# 9   False      2        3  ...                         9351
# 10  False      0        1  ...                         6403
# 11  False      1        5  ...                         5410
# 12  False      3        4  ...                        10754
# 13  False      1        0  ...                         6972
# 14  False      4        4  ...                        11474
# 15   True      5        7  ...                        10655
# 16   True      6        9  ...                        11844
# 17   True     10        2  ...                        17393
# 18   True      7       10  ...                        19650
# 19   True      0       12  ...                         3425
# 20  False     10        2  ...                        19273
# 21  False      0        5  ...                         1802
# 22  False      3        4  ...                         7977
# 23  False      2       12  ...                         8435
# 24  False      1        1  ...                         3416
# 25   True      3        6  ...                         9781
# 26   True      9       16  ...                        25782
# 27   True      1       11  ...                         5139
# 28   True     10        9  ...                        15016
# 29   True      5        6  ...                        14602
# 30  False      5        2  ...                        14431
# 31  False      1        3  ...                        23496
# 32  False      6        3  ...                        15385
# 33  False      1       10  ...                         8501
# 34  False      3        3  ...                        10986
# 35   True      2        8  ...                        15084
# 36   True      4        2  ...                        12803
# 37   True     14        7  ...                        25357
# 38   True      7        1  ...                        15301
# 39   True      1       15  ...                         5204
# 40   True      2       14  ...                        16632
# 41   True     11       12  ...                        19930
# 42   True     11       19  ...                        22558
# 43   True      2       16  ...                         9901
# 44   True      9       16  ...                        24575
# 45  False      6        5  ...                        13498
# 46  False      5        7  ...                        12019
# 47  False      5        8  ...                        18940
# 48  False      9        3  ...                        18554
# 49  False      1        9  ...                        13397
#
#     magicDamageDealtToChampions  physicalDamageDealtToChampions  goldEarned  \
# 0                          5030                            1294        6248
# 1                         15046                            1467        9051
# 2                          1650                           13338       11219
# 3                          2808                            6628        7080
# 4                          1500                            4549        8895
# 5                          2773                            4960        7046
# 6                           640                            7289        7927
# 7                           273                            2816        5759
# 8                          4617                             852        5497
# 9                           696                            8548        7100
# 10                         5421                             982        6215
# 11                         3687                            1722        5174
# 12                          120                            8642        6837
# 13                         6924                              48        6349
# 14                          673                           10801        8108
# 15                         2464                            8160        8619
# 16                         1974                            8480        9893
# 17                         2792                           14601       11352
# 18                        13641                             783        9848
# 19                         2163                             899        6542
# 20                        16942                            1927        9163
# 21                         1583                             219        4958
# 22                         1451                            6526        7718
# 23                         2199                            6161        7858
# 24                          318                            3098        6981
# 25                          489                            8991        8557
# 26                        22700                            2397       10026
# 27                         3651                            1156        7295
# 28                         1083                           13811       13095
# 29                         1609                           12680        8193
# 30                          154                           10756       10695
# 31                         7042                           14505        9589
# 32                         1398                           13937       10372
# 33                         5035                            2188        7377
# 34                         6587                             790        7483
